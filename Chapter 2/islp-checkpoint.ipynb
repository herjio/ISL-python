# %%
import numpy as np

# %%
x = np.array([1, 2, 3, 4, 5, 6])
print('beginning x:\n', x)
x_reshape = x.reshape((2, 3))
print('reshaped x:\n', x_reshape)
# Out:
# beginning x:
#  [1 2 3 4 5 6]
# reshaped x:
#  [[1 2 3]
#  [4 5 6]]

# %%
print(x.ndim)
print(x_reshape.ndim)
# Out:
# 1
# 2

# %%
x_reshape[1, 2]
# Out:
# 6

# %%
x_reshape.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
x = np.random.normal(size=50)
x
# Out:
# array([ 1.01034167, -2.43036471,  1.0903032 ,  0.41958849, -0.52814307,
#         1.69570065,  0.18275368,  1.5459664 ,  0.1167779 , -2.54868805,
#         0.33005396,  0.76191677, -0.76299025,  0.93980095, -0.73579564,
#        -0.99308353, -0.9033487 ,  1.35851887, -0.9798386 , -0.50488109,
#         0.18361497,  0.33694051,  0.10824869,  0.45146631,  0.53682022,
#        -0.50902909,  0.45179644, -0.47873337, -0.56395915, -0.82156145,
#        -0.39828724,  0.05755074,  1.48260055, -0.15235053,  0.61752532,
#         0.76655794,  0.50701376, -1.15897202, -0.22675075,  0.10162495,
#        -0.23098404,  1.14280174,  0.98043536,  0.48727998,  0.09408207,
#         0.45848054,  0.92147072,  2.24969948, -0.34314893, -0.67505165])

# %%
y = x + np.random.normal(loc=50, scale=1, size=50)
y
# Out:
# array([52.66848379, 47.29161284, 50.69648142, 50.13980013, 49.57564959,
#        50.88646465, 49.33192153, 49.30029579, 48.23650973, 47.87423944,
#        50.58964995, 50.69103532, 49.3715288 , 51.71289113, 47.61437476,
#        49.47490663, 50.10310836, 51.01418447, 47.9573146 , 49.98315315,
#        49.90376164, 50.97804526, 49.01618429, 50.66696091, 51.45064591,
#        48.21332259, 49.7869599 , 49.33668747, 50.86500658, 50.22497918,
#        49.23744106, 49.75154958, 52.09106545, 50.29458541, 50.94372903,
#        50.43625964, 50.27380131, 48.89584538, 50.30138378, 50.33463085,
#        48.51680003, 51.06273871, 51.65209856, 48.7030284 , 52.70768972,
#        51.93988622, 50.03894534, 51.52138333, 49.97253915, 48.97515676])

# %%
rng = np.random.default_rng(3)
y = rng.standard_normal(10)
np.mean(y), y.mean()
# Out:
# (-0.1126795190952861, -0.1126795190952861)

# %%
from matplotlib.pyplot import subplots
fig, ax = subplots(figsize=(8, 8))
x = rng.standard_normal(100)
y = rng.standard_normal(100)
ax.plot(x, y);

# %%
output = subplots(figsize=(8, 8))
fig = output[0]
ax = output[1]

# %%
fig, ax = subplots(figsize=(8, 8))
ax.plot(x, y, 'o');

# %%
fig, ax = subplots(figsize=(8, 8))
ax.scatter(x, y, marker='o');

# %%
fig, ax = subplots(figsize=(8, 8))
ax.scatter(x, y, marker='o')

# %%
fig, ax = subplots(figsize=(8, 8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig, ax = subplots(figsize=(8, 8))
#
# NameError: name 'subplots' is not defined

# %%
fig, ax = subplots(figsize=(8, 8))
ax.scatter(x, y, marker='o')
ax.set_xlabel("this is the x-axis")
ax.set_ylabel("this is the y-axis")
ax.set_title("Plot of X vs Y");

# %%
fig.set_size_inches(12,3)
fig

# %%
fig, axes = subplots(nrows=2,
ncols=3,
figsize=(15, 5))
